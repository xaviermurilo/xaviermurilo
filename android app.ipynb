# %%
import pandas as pd 
import plotly.express as px

# %%
df_app = pd.read_csv('apps.csv')

# %%
df_app.shape
# Out:
# (10841, 12)

# %%
df_app.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# Last_Updated         0
# Android_Ver          2
# dtype: int64

# %%
df_app.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# ...

# %%
df_app.sample(5)
# Out:
#                         App            Category  Rating  Reviews  Size_MBs  \
# 1484          BG Television              FAMILY     NaN        3       2.8
# 7315          How Old am I?              FAMILY     2.8     4635       3.9
# 4127  University of Florida              FAMILY     4.0      168       7.6
# 1418             DW Espanol  NEWS_AND_MAGAZINES     NaN        0       5.8
# 989                 FO RCBT       COMMUNICATION     NaN        5      15.0
#
#        Installs  Type Price Content_Rating            Genres  \
# 1484        500  Free     0       Everyone     Entertainment
# 7315  1,000,000  Free     0       Everyone     Entertainment
# 4127     10,000  Free     0       Everyone         Education
# 1418        100  Free     0       Everyone  News & Magazines
# 989         100  Free     0       Everyone     Communication
#
#            Last_Updated Android_Ver
# 1484  December 10, 2017  4.1 and up
# 7315    January 1, 2018  4.0 and up
# ...

# %%
df_app.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size_MBs          float64
# Installs           object
# Type               object
# Price              object
# Content_Rating     object
# Genres             object
# Last_Updated       object
# Android_Ver        object
# dtype: object

# %%
df_app.drop('Last_Updated', axis=1,inplace= True )

# %%
df_app.drop('Android_Ver', axis=1, inplace= True)

# %%
df_app.head(5)
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business

# %%
df_app['Rating'].isna().sum()
# Out:
# 1474

# %%
df_app_clean = df_app.dropna()

# %%
df_app_clean.shape
# Out:
# (9367, 10)

# %%
df_app_clean = df_app_clean.drop_duplicates(subset = ['App', 'Type', 'Price'])

# %%
df_app_clean.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL     5.0        4
# 28                                         Ra Ga Ba     GAME     5.0        2
# 47                                          Mu.F.O.     GAME     5.0        2
# 82                                 Brick Breaker BR     GAME     5.0        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21      25.0        1  Free      0       Everyone  Medical
# 28      20.0        1  Paid  $1.49       Everyone   Arcade
# 47      16.0        1  Paid  $0.99       Everyone   Arcade
# 82      19.0        5  Free      0       Everyone   Arcade
# 99       4.6        5  Free      0       Everyone  Medical

# %%
df_app_clean[df_app_clean.Rating == df_app_clean.Rating.max()]
# Out:
#                                                    App   Category  Rating  \
# 21                                 KBA-EZ Health Guide    MEDICAL     5.0
# 28                                            Ra Ga Ba       GAME     5.0
# 47                                             Mu.F.O.       GAME     5.0
# 82                                    Brick Breaker BR       GAME     5.0
# 99     Anatomy & Physiology Vocabulary Exam Review App    MEDICAL     5.0
# ...                                                ...        ...     ...
# 2680                               Florida Wildflowers     FAMILY     5.0
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News     COMICS     5.0
# 3030           CL Keyboard - Myanmar Keyboard (No Ads)      TOOLS     5.0
# 3115                                        Oración CX  LIFESTYLE     5.0
# 4058                          Ek Bander Ne Kholi Dukan     FAMILY     5.0
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating         Genres
# ...

# %%
df_app_clean[df_app_clean.Size_MBs == df_app_clean.Size_MBs.max()]
# Out:
#                                                     App            Category  \
# 1795                               Navi Radiography Pro             MEDICAL
# 3144                                         Vi Trainer  HEALTH_AND_FITNESS
# 4176   Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 7926                                          Post Bank             FINANCE
# 7927                        The Walking Dead: Our World                GAME
# 7928                      Stickman Legends: Shadow Wars                GAME
# 8718                  Mini Golf King - Multiplayer Game                GAME
# 8719                         Draft Simulator for FUT 18              SPORTS
# 9942                     Talking Babsy Baby: Baby Games           LIFESTYLE
# 9943                              Miami crime simulator                GAME
# 9944                       Gangster Town: Vice District              FAMILY
# ...

# %%
df_app_clean.sort_values('Reviews',ascending= False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %%
ratings = df_app_clean.Content_Rating.value_counts()

# %%
fig = px.pie(labels = ratings.index, values = ratings.values, names = ratings.index,hover_name= ratings.index, hole=0.5)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\plotly\express\_core.py:137: FutureWarning:
#
# Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
# ...

# %%
df_app_clean[df_app_clean.Installs == 1000000000]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size_MBs, Installs, Type, Price, Content_Rating, Genres]
# Index: []

# %%
df_app_clean.Installs = df_app_clean.Installs.astype(str).str.replace(',', "")

# %%
df_app_clean.Installs = pd.to_numeric(df_app_clean.Installs)

# %%
df_app_clean[df_app_clean.Installs == 1000000000]
# Out:
#                                             App             Category  Rating  \
# 10783                         Google Play Books  BOOKS_AND_REFERENCE     3.9
# 10784  Messenger – Text and Video Chat for Free        COMMUNICATION     4.0
# 10785                        WhatsApp Messenger        COMMUNICATION     4.4
# 10786              Google Chrome: Fast & Secure        COMMUNICATION     4.3
# 10787                                     Gmail        COMMUNICATION     4.3
# 10788                                  Hangouts        COMMUNICATION     4.0
# 10792             Skype - free IM & video calls        COMMUNICATION     4.1
# 10803                         Google Play Games        ENTERTAINMENT     4.3
# 10805                                  Facebook               SOCIAL     4.1
# 10806                                 Instagram               SOCIAL     4.5
# 10807                                   Google+               SOCIAL     4.2
# ...

# %%
df_app_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   int64
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 704.6+ KB

# %%
df_app_clean.Price = pd.to_numeric(df_app_clean.Price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$1.49"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [182], in <cell line: 1>()
# ----> 1 df_app_clean.Price = pd.to_numeric(df_app_clean.Price)
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
df_app_clean.Price = df_app_clean.Price.astype(str).str.replace('$', '')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10936\515630587.py:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df_app_clean.Price = pd.to_numeric(df_app_clean.Price)

# %%
df_app_clean.sort_values('Price', ascending= False).head(20)
# Out:
#                                  App   Category  Rating  Reviews   Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.300000
# 2461              I AM RICH PRO PLUS    FINANCE     4.0       36  41.000000
# 4606               I Am Rich Premium    FINANCE     4.1     1867   4.700000
# 3145              I am rich(premium)    FINANCE     3.5      472   0.942383
# 3554                      💎 I'm rich  LIFESTYLE     3.8      718  26.000000
# 5765                       I am rich  LIFESTYLE     3.8     3547   1.800000
# 1946  I am rich (Most expensive app)    FINANCE     4.1      129   2.700000
# 2775                   I Am Rich Pro     FAMILY     4.4      201   2.700000
# 3221                  I am Rich Plus     FAMILY     4.0      856   8.700000
# 3114                       I am Rich    FINANCE     4.3      180   3.800000
# 1331          most expensive app (H)     FAMILY     4.3        6   1.500000
# ...

# %%
df_app_clean = df_app_clean[df_app_clean.Price < 250]

# %%
df_app_clean.sort_values('Price', ascending = False)
# Out:
#                                App   Category  Rating   Reviews  Size_MBs  \
# 2281     Vargo Anesthesia Mega App    MEDICAL     4.6        92      32.0
# 1407                  LTC AS Legal    MEDICAL     4.0         6       1.3
# 2629              I am Rich Person  LIFESTYLE     4.2       134       1.8
# 2481       A Manual of Acupuncture    MEDICAL     3.5       214      68.0
# 2463            PTA Content Master    MEDICAL     4.2        64      41.0
# ...                            ...        ...     ...       ...       ...
# 4508   myAir™ for Air10™ by ResMed    MEDICAL     3.7       236      18.0
# 4507                 AK Math Coach     FAMILY     3.6       283      18.0
# 4506          Forgotten Hill: Fall       GAME     4.4      1063      18.0
# 4505                AE Video Poker       GAME     4.0       721      18.0
# 10835               Subway Surfers       GAME     4.5  27722264      76.0
#
#          Installs  Type  Price Content_Rating     Genres
# ...

# %%
df_app_clean['Revenue_Estimate'] = df_app_clean.Price * df_app_clean.Installs
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10936\1827624396.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_app_clean.sort_values('Revenue_Estimate', ascending = False).head(20)
# Out:
#                                                    App         Category  \
# 9220                                         Minecraft           FAMILY
# 8825                                     Hitman Sniper             GAME
# 7151                     Grand Theft Auto: San Andreas             GAME
# 7477                               Facetune - For Free      PHOTOGRAPHY
# 7977                           Sleep as Android Unlock        LIFESTYLE
# 6594                               DraStic DS Emulator             GAME
# 6082                                      Weather Live          WEATHER
# 7954                                       Bloons TD 5           FAMILY
# 7633                           Five Nights at Freddy's             GAME
# 6746                        Card Wars - Adventure Time           FAMILY
# 6856                                           Threema    COMMUNICATION
# 7044                                            Tasker            TOOLS
# ...

# %%
df_app_clean.Category.nunique()
# Out:
# 33

# %%
top_10_category = df_app_clean.Category.value_counts()[:10]
top_10_category
# Out:
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %%
px.bar(x=top_10_category.index, y=top_10_category.values)
# Out:
# <div>                            <div id="603ee71e-f606-4f36-83ff-17b7b8d00a09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("603ee71e-f606-4f36-83ff-17b7b8d00a09")) {                    Plotly.newPlot(                        "603ee71e-f606-4f36-83ff-17b7b8d00a09",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","PRODUCTIVITY","PERSONALIZATION","LIFESTYLE","FINANCE","MEDICAL","PHOTOGRAPHY","BUSINESS"],"xaxis":"x","y":[1606,910,719,301,298,297,296,292,263,262],"yaxis":"y","type":"bar"}],                        {"templ
# ...

# %%
df_app_clean.groupby('Category').sum().head(10)
# Out:
#                      Rating    Reviews     Size_MBs     Installs  Price  \
# Category
# ART_AND_DESIGN        265.8    1419135   771.600000    114233100   5.97
# AUTO_AND_VEHICLES     305.9    1163630  1447.096289     53129800   1.99
# BEAUTY                179.7     395133   619.500000     26916200   0.00
# BOOKS_AND_REFERENCE   734.3   16720905  2157.089063   1665791655  23.88
# BUSINESS             1073.3    9700938  3385.418750    692018120  64.41
# COMICS                225.8    2340740   689.278320     44931100   0.00
# COMMUNICATION        1059.2  285828436  2494.686719  11039241530  56.69
# DATING                532.0    3623311  2286.400000    140912410  18.97
# EDUCATION             515.0   13363372  1880.556641    352852000  17.96
# ENTERTAINMENT         421.8   34762650  1830.100000   2113660000   7.98
#
#                      Revenue_Estimate
# Category
# ART_AND_DESIGN                31840.0
# AUTO_AND_VEHICLES             99500.0
# ...

# %%
category_install = df_app_clean.groupby('Category').agg({'Installs': 'sum'})
category_install.sort_values('Installs', ascending=True, inplace=True)

# %%
h_bar = px.bar(x=category_install.Installs, y=category_install.index)
h_bar.show()
# Out:
# <div>                            <div id="bb0dea90-ce59-4d6b-b9a4-1af88cd398d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb0dea90-ce59-4d6b-b9a4-1af88cd398d9")) {                    Plotly.newPlot(                        "bb0dea90-ce59-4d6b-b9a4-1af88cd398d9",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15949410,26916200,31116110,39162676,44931100,52083000,53129800,97082000,114233100,140912410,211677750,352852000,361096500,455249400,503267560,503611120,692018120,1096431465,1134006220,1400331540,1532352930,1665791655,2113660000,2369
# ...

# %% [markdown]
# **Here we can understand that the most

# %%
cat_number = df_app_clean.groupby('Category').agg({'App': 'count'})

# %%
at_merged_df = pd.merge(cat_number, category_install, on='Category', how="inner")

# %%
at_merged_df.sample()
# Out:
#                   App    Installs
# Category
# TRAVEL_AND_LOCAL  187  2894859300

# %%
    scatter = px.scatter(at_merged_df, # data
                        x='App', # column name
                        y='Installs',
                        title='Category Concentration',
                        size='App',
                        hover_name=at_merged_df.index,
                        color='Installs')
     
    scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                          yaxis_title="Installs",
                          yaxis=dict(type='log'))
     
    scatter.show()
# Out:
# <div>                            <div id="19bb72be-d39c-4f1c-9daf-ab078ed0d4fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19bb72be-d39c-4f1c-9daf-ab078ed0d4fc")) {                    Plotly.newPlot(                        "19bb72be-d39c-4f1c-9daf-ab078ed0d4fc",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>App=%{marker.size}<br>Installs=%{marker.color}<extra></extra>","hovertext":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION"
# ...

# %%
df_app_clean.sample()
# Out:
#                           App        Category  Rating  Reviews  Size_MBs  \
# 5167  Easy and quick desserts  FOOD_AND_DRINK     4.6     1398      10.0
#
#       Installs  Type  Price Content_Rating        Genres  Revenue_Estimate
# 5167    100000  Free    0.0   Everyone 10+  Food & Drink               0.0

# %%
df_app_clean.Genres.nunique()
# Out:
# 114

# %%
df_app_clean.Genres.value_counts().sort_values(ascending=True)[0:5]
# Out:
# Lifestyle;Pretend Play      1
# Strategy;Education          1
# Adventure;Education         1
# Role Playing;Brain Games    1
# Tools;Education             1
# Name: Genres, dtype: int64

# %%
df_free_paid = df_app_clean.groupby(['Category', 'Type'], as_index = False).agg({'App': 'count'})

# %%
df_free_paid.sort_values('Category')
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
df_app_clean.sample()
# Out:
#               App   Category  Rating  Reviews  Size_MBs  Installs  Type  \
# 3539  EK Platinum  LIFESTYLE     3.8       52      10.0     10000  Free
#
#       Price Content_Rating     Genres  Revenue_Estimate
# 3539    0.0       Everyone  Lifestyle               0.0

# %%
    box = px.box(df_app_clean,
                 y='Installs',
                 x='Type',
                 color='Type',
                 notched=True,
                 points='all',
                 title='How Many Downloads are Paid Apps Giving Up?')
     
    box.update_layout(yaxis=dict(type='log'))
     
    box.show()
# Out:
# <div>                            <div id="04c344a2-1cc5-41b0-8870-a1d7052db55d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04c344a2-1cc5-41b0-8870-a1d7052db55d")) {                    Plotly.newPlot(                        "04c344a2-1cc5-41b0-8870-a1d7052db55d",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}<br>Installs=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free"
# ...

# %%
    df_paid_apps = df_app_clean[df_app_clean['Type'] == 'Paid']

    box = px.box(df_paid_apps, 
                 x='Category', 
                 y='Revenue_Estimate',
                 title='How Much Can Paid Apps Earn?')
     
    box.update_layout(xaxis_title='Category',
                      yaxis_title='Paid App Ballpark Revenue',
                      xaxis={'categoryorder':'min ascending'},
                      yaxis=dict(type='log'))
     
     
    box.show()
# Out:
# <div>                            <div id="357711f4-3b7d-4f0c-b6ec-3cb880cf8d16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("357711f4-3b7d-4f0c-b6ec-3cb880cf8d16")) {                    Plotly.newPlot(                        "357711f4-3b7d-4f0c-b6ec-3cb880cf8d16",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Revenue_Estimate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZAT
# ...
